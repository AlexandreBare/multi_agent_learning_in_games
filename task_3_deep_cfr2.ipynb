# %%
# !pip install --upgrade open_spiel

from open_spiel.python import policy
from open_spiel.python.algorithms import deep_cfr_tf2
from open_spiel.python.algorithms import expected_game_score
from open_spiel.python.algorithms import exploitability
import pyspiel
# Out:
# Requirement already satisfied: open_spiel in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.7/dist-packages (from open_spiel) (21.4.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from open_spiel) (1.21.6)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.7/dist-packages (from open_spiel) (1.7.3)
# Requirement already satisfied: absl-py>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from open_spiel) (1.0.0)
# Requirement already satisfied: pip>=20.0.2 in /usr/local/lib/python3.7/dist-packages (from open_spiel) (21.1.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.10.0->open_spiel) (1.15.0)

# %%
num_iterations = 400
num_iter_each = 4 #set this to 400 so that it is as same as the example on github, but I am trying to see whether we can plot each iteration
num_traversal = 40

game = pyspiel.load_game('kuhn_poker')
deep_cfr_solver = deep_cfr_tf2.DeepCFRSolver(
    game,
    policy_network_layers=(16,),
    advantage_network_layers=(16,),
    num_iterations=num_iter_each,
    num_traversals=num_traversal,
    learning_rate=1e-3,
    batch_size_advantage=128,
    batch_size_strategy=1024,
    memory_capacity=1e7,
    policy_network_train_steps=400,
    advantage_network_train_steps=20,
    reinitialize_advantage_networks=False,
    infer_device="cpu",
    train_device="cpu")

for i in range(num_iterations // num_iter_each):
  print(f"iteration: {i}")
  _, advantage_losses, policy_loss = deep_cfr_solver.solve()
 # for player, losses in advantage_losses.items():
 #   print("Advantage for player {}: {}".format(player,losses[:2] + ["..."] + losses[-2:]))
 #   print("Advantage Buffer Size for player {}: {}".format(player, len(deep_cfr_solver.advantage_buffers[player])))

#  print("Strategy Buffer Size: {}".format(len(deep_cfr_solver.strategy_buffer)))
  print("Final policy loss: {}".format(policy_loss))

  average_policy = policy.tabular_policy_from_callable(game, deep_cfr_solver.action_probabilities)

  conv = exploitability.nash_conv(game, average_policy)
  exp = exploitability.exploitability(game, average_policy)
  print(f"NashConv: {conv}")
  print(f"Exploitability: {exp}")

#  average_policy_values = expected_game_score.policy_value(
#      game.new_initial_state(), [average_policy] * 2)
#  print("Computed player 0 value: {}".format(average_policy_values[0]))
#  print("Computed player 1 value: {}".format(average_policy_values[1]))
  print()
# Out:
# iteration: 0
# Final policy loss: 0.03564165532588959
# NashConv: 0.8016757269971324
# Exploitability: 0.4008378634985662
#
# iteration: 1
# Final policy loss: 0.044525474309921265
# NashConv: 0.558005497071003
# Exploitability: 0.2790027485355015
#
# iteration: 2
# Final policy loss: 0.04287794604897499
# NashConv: 0.47397062391173056
# Exploitability: 0.23698531195586528
#
# iteration: 3
# Final policy loss: 0.047114867717027664
# NashConv: 0.3981467962463053
# Exploitability: 0.19907339812315264
#
# iteration: 4
# Final policy loss: 0.05440378189086914
# NashConv: 0.3338458445140342
# Exploitability: 0.1669229222570171
#
# iteration: 5
# Final policy loss: 0.06457510590553284
# NashConv: 0.25687932256799256
# Exploitability: 0.12843966128399628
#
# iteration: 6
# Final policy loss: 0.08764326572418213
# NashConv: 0.2727949743483316
# Exploitability: 0.1363974871741658
#
# iteration: 7
# Final policy loss: 0.08211521804332733
# NashConv: 0.22686152826079997
# Exploitability: 0.11343076413039999
#
# iteration: 8
# Final policy loss: 0.07931879162788391
# NashConv: 0.2079019103246873
# Exploitability: 0.10395095516234365
#
# iteration: 9
# Final policy loss: 0.07572664320468903
# NashConv: 0.1668535051409471
# Exploitability: 0.08342675257047355
#
# iteration: 10
# Final policy loss: 0.07669055461883545
# NashConv: 0.14167143968683782
# Exploitability: 0.07083571984341891
#
# iteration: 11
# Final policy loss: 0.07168182730674744
# NashConv: 0.17736366184792746
# Exploitability: 0.08868183092396373
#
# iteration: 12
# Final policy loss: 0.08197176456451416
# NashConv: 0.2155896293379902
# Exploitability: 0.1077948146689951
#
# iteration: 13
# Final policy loss: 0.09909696877002716
# NashConv: 0.2304176880783113
# Exploitability: 0.11520884403915566
#
# iteration: 14
# Final policy loss: 0.10607536137104034
# NashConv: 0.23070845817654873
# Exploitability: 0.11535422908827436
#
# iteration: 15
# Final policy loss: 0.13033220171928406
# NashConv: 0.17690443026906227
# Exploitability: 0.08845221513453114
#
# iteration: 16
# Final policy loss: 0.12635374069213867
# NashConv: 0.13054410082823303
# Exploitability: 0.06527205041411652
#
# iteration: 17
# Final policy loss: 0.13474984467029572
# NashConv: 0.10087521591490617
# Exploitability: 0.050437607957453084
#
# iteration: 18
# Final policy loss: 0.11308157444000244
# NashConv: 0.08137765025907562
# Exploitability: 0.04068882512953781
#
# iteration: 19
# Final policy loss: 0.11613453924655914
# NashConv: 0.11415235287108388
# Exploitability: 0.05707617643554194
#
# iteration: 20
# Final policy loss: 0.11381670832633972
# NashConv: 0.14329082320217024
# Exploitability: 0.07164541160108512
#
# iteration: 21
# Final policy loss: 0.1116093248128891
# NashConv: 0.13208022672051672
# Exploitability: 0.06604011336025836
#
# iteration: 22
# Final policy loss: 0.10841517150402069
# NashConv: 0.13613203793443923
# Exploitability: 0.06806601896721962
#
# iteration: 23
# Final policy loss: 0.10342925786972046
# NashConv: 0.12848270662627048
# Exploitability: 0.06424135331313524
#
# iteration: 24
# Final policy loss: 0.10826684534549713
# NashConv: 0.11812989876001029
# Exploitability: 0.059064949380005144
#
# iteration: 25
# Final policy loss: 0.08467914909124374
# NashConv: 0.09568499995314766
# Exploitability: 0.04784249997657383
#
# iteration: 26
# Final policy loss: 0.10033716261386871
# NashConv: 0.08365800977284732
# Exploitability: 0.04182900488642366
#
# iteration: 27
# Final policy loss: 0.09968261420726776
# NashConv: 0.06282169541674915
# Exploitability: 0.03141084770837457
#
# iteration: 28
# Final policy loss: 0.09115274250507355
# NashConv: 0.0611425296623096
# Exploitability: 0.0305712648311548
#
# iteration: 29
# Final policy loss: 0.08494152873754501
# NashConv: 0.061932137836749335
# Exploitability: 0.030966068918374667
#
# iteration: 30
# Final policy loss: 0.08391361683607101
# NashConv: 0.06665339472121262
# Exploitability: 0.03332669736060631
#
# iteration: 31
# Final policy loss: 0.08466984331607819
# NashConv: 0.07689063274817265
# Exploitability: 0.038445316374086325
#
# iteration: 32
# Final policy loss: 0.08571925759315491
# NashConv: 0.09288025549177864
# Exploitability: 0.04644012774588932
#
# iteration: 33
# Final policy loss: 0.0910218209028244
# NashConv: 0.1237193411943458
# Exploitability: 0.0618596705971729
#
# iteration: 34
# Final policy loss: 0.09355799853801727
# NashConv: 0.13201980255429568
# Exploitability: 0.06600990127714784
#
# iteration: 35
# Final policy loss: 0.08670011907815933
# NashConv: 0.11040056970866469
# Exploitability: 0.05520028485433234
#
# iteration: 36
# Final policy loss: 0.09401346743106842
# NashConv: 0.11624120155506285
# Exploitability: 0.05812060077753142
#
# iteration: 37
# Final policy loss: 0.0999097228050232
# NashConv: 0.09284164431481085
# Exploitability: 0.04642082215740542
#
# iteration: 38
# Final policy loss: 0.1046588197350502
# NashConv: 0.08944825250913835
# Exploitability: 0.044724126254569174
#
# iteration: 39
# Final policy loss: 0.10367030650377274
# NashConv: 0.07521133354367865
# Exploitability: 0.037605666771839324
#
# iteration: 40
# Final policy loss: 0.10884422063827515
# NashConv: 0.07537133875820146
# Exploitability: 0.03768566937910073
#
# iteration: 41
# Final policy loss: 0.11176448315382004
# NashConv: 0.07754215475213744
# Exploitability: 0.03877107737606872
#
# iteration: 42
# Final policy loss: 0.10103145241737366
# NashConv: 0.06979508344982988
# Exploitability: 0.03489754172491494
#
# iteration: 43
# Final policy loss: 0.09508906304836273
# NashConv: 0.06614638171710391
# Exploitability: 0.033073190858551954
#
# iteration: 44
# Final policy loss: 0.10139664262533188
# NashConv: 0.07579006412810918
# Exploitability: 0.03789503206405459
#
# iteration: 45
# Final policy loss: 0.09299640357494354
# NashConv: 0.07211146831976367
# Exploitability: 0.036055734159881836
#
# iteration: 46
# Final policy loss: 0.08621133863925934
# NashConv: 0.08743888508786873
# Exploitability: 0.04371944254393437
#
# iteration: 47
# Final policy loss: 0.08277438580989838
# NashConv: 0.08994778053986224
# Exploitability: 0.04497389026993112
#
# iteration: 48
# Final policy loss: 0.09244528412818909
# NashConv: 0.0963857646253381
# Exploitability: 0.04819288231266905
#
# iteration: 49
# Final policy loss: 0.08293650299310684
# NashConv: 0.09686700508633111
# Exploitability: 0.04843350254316556
#
# iteration: 50
# Final policy loss: 0.09662526845932007
# NashConv: 0.09431678049758208
# Exploitability: 0.04715839024879104
#
# iteration: 51
# Final policy loss: 0.08955302834510803
# NashConv: 0.07904163533474745
# Exploitability: 0.039520817667373725
#
# iteration: 52
# Final policy loss: 0.0889275074005127
# NashConv: 0.07487687165826357
# Exploitability: 0.03743843582913178
#
# iteration: 53
# Final policy loss: 0.08035628497600555
# NashConv: 0.08133966466502396
# Exploitability: 0.04066983233251198
#
# iteration: 54
# Final policy loss: 0.08229611814022064
# NashConv: 0.07720692175979682
# Exploitability: 0.03860346087989841
#
# iteration: 55
# Final policy loss: 0.07850367575883865
# NashConv: 0.07875762524332691
# Exploitability: 0.039378812621663456
#
# iteration: 56
# Final policy loss: 0.08401183784008026
# NashConv: 0.07087875460879273
# Exploitability: 0.03543937730439636
#
# iteration: 57
# Final policy loss: 0.07875744998455048
# NashConv: 0.06860794055982788
# Exploitability: 0.03430397027991394
#
# iteration: 58
# Final policy loss: 0.08609742671251297
# NashConv: 0.07335884915932644
# Exploitability: 0.03667942457966322
#
# iteration: 59
# Final policy loss: 0.07449851185083389
# NashConv: 0.06484495561884673
# Exploitability: 0.03242247780942337
#
# iteration: 60
# Final policy loss: 0.08296575397253036
# NashConv: 0.06877887817965728
# Exploitability: 0.03438943908982864
#
# iteration: 61
# Final policy loss: 0.08662338554859161
# NashConv: 0.07808239131993322
# Exploitability: 0.03904119565996661
#
# iteration: 62
# Final policy loss: 0.07900814712047577
# NashConv: 0.07346691975633646
# Exploitability: 0.03673345987816823
#
# iteration: 63
# Final policy loss: 0.08655506372451782
# NashConv: 0.06779844560247733
# Exploitability: 0.033899222801238665
#
# iteration: 64
# Final policy loss: 0.09399546682834625
# NashConv: 0.05842581799101848
# Exploitability: 0.02921290899550924
#
# iteration: 65
# Final policy loss: 0.09118868410587311
# NashConv: 0.08713633107596053
# Exploitability: 0.043568165537980263
#
# iteration: 66
# Final policy loss: 0.0947180688381195
# NashConv: 0.07706949111952938
# Exploitability: 0.03853474555976469
#
# iteration: 67
# Final policy loss: 0.11200028657913208
# NashConv: 0.08242763094600652
# Exploitability: 0.04121381547300326
#
# iteration: 68
# Final policy loss: 0.095920130610466
# NashConv: 0.08166495514509725
# Exploitability: 0.040832477572548626
#
# iteration: 69
# Final policy loss: 0.0935915857553482
# NashConv: 0.08086164168491411
# Exploitability: 0.040430820842457055
#
# iteration: 70
# Final policy loss: 0.08994053304195404
# NashConv: 0.08998693217623921
# Exploitability: 0.044993466088119605
#
# iteration: 71
# Final policy loss: 0.0898333340883255
# NashConv: 0.07486256427693544
# Exploitability: 0.03743128213846772
#
# iteration: 72
# Final policy loss: 0.09548141807317734
# NashConv: 0.08648977706427596
# Exploitability: 0.04324488853213798
#
# iteration: 73
# Final policy loss: 0.09477357566356659
# NashConv: 0.07515007357275899
# Exploitability: 0.037575036786379495
#
# iteration: 74
# Final policy loss: 0.08420008420944214
# NashConv: 0.0851831949576104
# Exploitability: 0.0425915974788052
#
# iteration: 75
# Final policy loss: 0.094368115067482
# NashConv: 0.07351153576102992
# Exploitability: 0.03675576788051496
#
# iteration: 76
# Final policy loss: 0.08131444454193115
# NashConv: 0.06548514819825346
# Exploitability: 0.03274257409912673
#
# iteration: 77
# Final policy loss: 0.0774172842502594
# NashConv: 0.0769555593760054
# Exploitability: 0.0384777796880027
#
# iteration: 78
# Final policy loss: 0.08431507647037506
# NashConv: 0.07402577028147234
# Exploitability: 0.03701288514073617
#
# iteration: 79
# Final policy loss: 0.0981064885854721
# NashConv: 0.08104933286721921
# Exploitability: 0.04052466643360961
#
# iteration: 80
# Final policy loss: 0.07613429427146912
# NashConv: 0.06767025073088268
# Exploitability: 0.03383512536544134
#
# iteration: 81
# Final policy loss: 0.09094437956809998
# NashConv: 0.06802073905192663
# Exploitability: 0.03401036952596331
#
# iteration: 82
# Final policy loss: 0.08439033478498459
# NashConv: 0.07277934072999914
# Exploitability: 0.03638967036499957
#
# iteration: 83
# Final policy loss: 0.08807536959648132
# NashConv: 0.06808610419115141
# Exploitability: 0.034043052095575704
#
# iteration: 84
# Final policy loss: 0.08697090297937393
# NashConv: 0.07574898303753658
# Exploitability: 0.03787449151876829
#
# iteration: 85
# Final policy loss: 0.07856433838605881
# NashConv: 0.04502283989111633
# Exploitability: 0.022511419945558164
#
# iteration: 86
# Final policy loss: 0.07881778478622437
# NashConv: 0.028039415372189458
# Exploitability: 0.014019707686094729
#
# iteration: 87
# Final policy loss: 0.07070038467645645
# NashConv: 0.02782281871729142
# Exploitability: 0.01391140935864571
#
# iteration: 88
# Final policy loss: 0.07909062504768372
# NashConv: 0.03597444508047887
# Exploitability: 0.017987222540239434
#
# iteration: 89
# Final policy loss: 0.07349392026662827
# NashConv: 0.0382516167179337
# Exploitability: 0.01912580835896685
#
# iteration: 90
# Final policy loss: 0.06963801383972168
# NashConv: 0.026616188008338648
# Exploitability: 0.013308094004169324
#
# iteration: 91
# Final policy loss: 0.07309851050376892
# NashConv: 0.03263169181368469
# Exploitability: 0.016315845906842347
#
# iteration: 92
# Final policy loss: 0.06991904973983765
# NashConv: 0.015237110260505837
# Exploitability: 0.007618555130252919
#
# iteration: 93
# Final policy loss: 0.07824510335922241
# NashConv: 0.0436558696302089
# Exploitability: 0.02182793481510445
#
# iteration: 94
# Final policy loss: 0.07444945722818375
# NashConv: 0.025768822163761473
# Exploitability: 0.012884411081880737
#
# iteration: 95
# Final policy loss: 0.07248975336551666
# NashConv: 0.028623194369108595
# Exploitability: 0.014311597184554298
#
# iteration: 96
# Final policy loss: 0.07448501884937286
# NashConv: 0.02351192369295163
# Exploitability: 0.011755961846475815
#
# iteration: 97
# Final policy loss: 0.07724422216415405
# NashConv: 0.03744744244021225
# Exploitability: 0.018723721220106126
#
# iteration: 98
# Final policy loss: 0.07410663366317749
# NashConv: 0.032451216652956805
# Exploitability: 0.016225608326478402
#
# iteration: 99
# Final policy loss: 0.07956786453723907
# NashConv: 0.02692218555578474
# Exploitability: 0.01346109277789237
